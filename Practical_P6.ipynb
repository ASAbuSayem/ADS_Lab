# %% [markdown]
# **PRACTICAL 6: IMPLEMENT BUBBLE SORT**

# %%
# Function to perform Bubble Sort
def bubble_sort(arr):
    n = len(arr)
    # Outer loop runs for each element
    for i in range(n - 1):
        # Inner loop for adjacent comparison
        for j in range(0, n - i - 1):
            # Compare and swap if needed
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
        # Print the array after each pass
        print(f"After pass {i+1}: {arr}")

# %%
# MAIN PROGRAM
# Taking input from user
n = int(input("Enter number of elements: "))
arr = []

for i in range(n):
    val = int(input(f"Enter element {i+1}: "))
    arr.append(val)

print("\nOriginal Array:", arr)

# Calling the sorting function
bubble_sort(arr)

# Final sorted array
print("\nSorted Array in Ascending Order:", arr)
# Out:
# Enter number of elements: 5
# Enter element 1: 10
# Enter element 2: 20
# Enter element 3: 30
# Enter element 4: 40
# Enter element 5: 50
#
# Original Array: [10, 20, 30, 40, 50]
# After pass 1: [10, 20, 30, 40, 50]
# After pass 2: [10, 20, 30, 40, 50]
# After pass 3: [10, 20, 30, 40, 50]
# After pass 4: [10, 20, 30, 40, 50]
#
# Sorted Array in Ascending Order: [10, 20, 30, 40, 50]
